# %% [markdown]
# # 📊 Evaluating Untested STT + MT Combinations Based on Efficiency

# %% [markdown]
# ## 🎯 Goal
#
# We want to estimate which STT+MT pairs offer the best trade-off between **quality** and **speed**.
#
# We combine:
#
# - **Whisper models** (STT): e.g., tiny, base, small, etc.
# - **Translation models**: e.g., Google Translate, DeepL, GPT-4o, etc.
#
# Each model has:
# - A **quality score** (higher is better)
# - A **generation time** in seconds (lower is better)
#
# The main metric is:
#
# > **Efficiency = (STT Score + MT Score) / (STT Time + MT Time)**

# %%
import pandas as pd
from IPython.display import display, Markdown

# === STT (Speech-to-Text) model scores and generation times (in seconds)
whisper_data = {
    "tiny": (13, 12),
    "base": (15, 8),
    "small": (16, 8),
    "medium": (15, 17),
    "large-v1": (17, 36),
    "large-v2": (19, 17),
    "large-v3": (19, 33),
    "large-turbo-v3": (18, 21)
}

# === MT (Machine Translation) model scores and generation times (in seconds)
translation_data = {
    "Google Translate V1": (10, 1),
    "DeepL V2": (13, 3),
    "ChatGPT mini 3o": (17, 4),
    "GPT-4o mini": (18, 8),
    "GPT-4o": (18, 6),
    "GPT-4o turbo": (18, 8),
    "GPT-3.5 turbo": (14, 5),
    "GPT-4": (18, 11),
    "MyMemory": (17, 3),
    "Groq": (13, 3),
    "Winstxnhdw": (10, 24),
    "Ollama": (14, 4),
    "DeepSeek R1": (12, 58),
    "Gemma 3": (13, 6),
    "ZongweiGemma3": (11, 5),
    "Gemini 2.0 Flash": (15, 2)
}

# === Already tested combinations (to be excluded)
tested_combinations = {
    ("tiny", "Google Translate V1"),
    ("base", "DeepL V2"),
    ("small", "ChatGPT mini 3o"),
    ("small", "GPT-4o mini"),
    ("small", "GPT-4o"),
    ("small", "GPT-4o turbo"),
    ("small", "GPT-3.5 turbo"),
    ("small", "GPT-4"),
    ("medium", "MyMemory"),
    ("large-v1", "Groq"),
    ("large-v2", "Winstxnhdw"),
    ("large-v3", "Ollama"),
    ("large-v3", "DeepSeek R1"),
    ("large-v3", "Gemma 3"),
    ("large-v3", "ZongweiGemma3"),
    ("large-turbo-v3", "Gemini 2.0 Flash")
}

# === Build and evaluate all untested combinations
combinations = []
for whisper, (stt_score, stt_time) in whisper_data.items():
    for trans, (mt_score, mt_time) in translation_data.items():
        if (whisper, trans) in tested_combinations:
            continue
        total_score = stt_score + mt_score
        total_time = stt_time + mt_time  # seconds
        efficiency = round(total_score / total_time, 3)
        combinations.append({
            "STT Model (Whisper)": whisper,
            "MT Model (Translator)": trans,
            "STT Quality Score": stt_score,
            "MT Quality Score": mt_score,
            "Total Score (Quality)": total_score,
            "Total Time (sec)": total_time,
            "Efficiency (Score ÷ Time)": efficiency
        })

# === Sort and display
df = pd.DataFrame(combinations)
df_sorted = df.sort_values("Efficiency (Score ÷ Time)", ascending=False).reset_index(drop=True)

# === Explanation block
display(Markdown("""
## 🔍 Suggested Untested Model Combinations Ranked by Efficiency

This table shows untested combinations of **STT** (Speech-to-Text) and **MT** (Machine Translation) models.
They are ranked by **efficiency**, calculated using the formula:

> **Efficiency = (STT Score + MT Score) / (STT Time + MT Time)**  
> *Time is measured in seconds.*

- **STT Score**: Quality of converting spoken German to written German.
- **MT Score**: Quality of translating German text to English.
- **Time (sec)**: Combined generation time for both STT and MT.
- **Efficiency**: Higher means better quality per second.

Use this to prioritize the most promising model pairs to test next.
"""))

# === Final styled output
display(df_sorted.style.background_gradient(cmap="Greens", subset=["Efficiency (Score ÷ Time)"]))
# Out:
# ## 🔍 Suggested Untested Model Combinations Ranked by Efficiency
#
# This table shows untested combinations of **STT** (Speech-to-Text) and **MT** (Machine Translation) models.
# They are ranked by **efficiency**, calculated using the formula:
#
# > **Efficiency = (STT Score + MT Score) / (STT Time + MT Time)**
# > *Time is measured in seconds.*
#
# - **STT Score**: Quality of converting spoken German to written German.
# - **MT Score**: Quality of translating German text to English.
# - **Time (sec)**: Combined generation time for both STT and MT.
# - **Efficiency**: Higher means better quality per second.
#
# Use this to prioritize the most promising model pairs to test next.
# <style type="text/css">
# #T_68897_row0_col6 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_68897_row1_col6, #T_68897_row2_col6 {
#   background-color: #005020;
#   color: #f1f1f1;
# }
# #T_68897_row3_col6 {
#   background-color: #005a24;
#   color: #f1f1f1;
# }
# #T_68897_row4_col6 {
#   background-color: #005c25;
#   color: #f1f1f1;
# }
# #T_68897_row5_col6 {
#   background-color: #00692a;
#   color: #f1f1f1;
# }
# #T_68897_row6_col6 {
#   background-color: #087432;
#   color: #f1f1f1;
# }
# #T_68897_row7_col6, #T_68897_row8_col6 {
#   background-color: #0b7734;
#   color: #f1f1f1;
# }
# #T_68897_row9_col6 {
#   background-color: #147e3a;
#   color: #f1f1f1;
# }
# #T_68897_row10_col6 {
#   background-color: #19833e;
#   color: #f1f1f1;
# }
# #T_68897_row11_col6 {
#   background-color: #218944;
#   color: #f1f1f1;
# }
# #T_68897_row12_col6 {
#   background-color: #278f48;
#   color: #f1f1f1;
# }
# #T_68897_row13_col6 {
#   background-color: #319a50;
#   color: #f1f1f1;
# }
# #T_68897_row14_col6 {
#   background-color: #3fa85b;
#   color: #f1f1f1;
# }
# #T_68897_row15_col6 {
#   background-color: #3fa95c;
#   color: #f1f1f1;
# }
# #T_68897_row16_col6, #T_68897_row17_col6 {
#   background-color: #40aa5d;
#   color: #f1f1f1;
# }
# #T_68897_row18_col6, #T_68897_row19_col6, #T_68897_row20_col6, #T_68897_row21_col6 {
#   background-color: #48ae60;
#   color: #f1f1f1;
# }
# #T_68897_row22_col6 {
#   background-color: #5bb86a;
#   color: #f1f1f1;
# }
# #T_68897_row23_col6 {
#   background-color: #66bd6f;
#   color: #f1f1f1;
# }
# #T_68897_row24_col6 {
#   background-color: #68be70;
#   color: #000000;
# }
# #T_68897_row25_col6, #T_68897_row26_col6, #T_68897_row27_col6 {
#   background-color: #70c274;
#   color: #000000;
# }
# #T_68897_row28_col6 {
#   background-color: #72c375;
#   color: #000000;
# }
# #T_68897_row29_col6 {
#   background-color: #73c476;
#   color: #000000;
# }
# #T_68897_row30_col6 {
#   background-color: #76c578;
#   color: #000000;
# }
# #T_68897_row31_col6, #T_68897_row32_col6 {
#   background-color: #80ca80;
#   color: #000000;
# }
# #T_68897_row33_col6, #T_68897_row34_col6 {
#   background-color: #81ca81;
#   color: #000000;
# }
# #T_68897_row35_col6 {
#   background-color: #83cb82;
#   color: #000000;
# }
# #T_68897_row36_col6 {
#   background-color: #84cc83;
#   color: #000000;
# }
# #T_68897_row37_col6 {
#   background-color: #86cc85;
#   color: #000000;
# }
# #T_68897_row38_col6, #T_68897_row39_col6 {
#   background-color: #88ce87;
#   color: #000000;
# }
# #T_68897_row40_col6 {
#   background-color: #8bcf89;
#   color: #000000;
# }
# #T_68897_row41_col6 {
#   background-color: #8ed08b;
#   color: #000000;
# }
# #T_68897_row42_col6, #T_68897_row43_col6 {
#   background-color: #91d28e;
#   color: #000000;
# }
# #T_68897_row44_col6 {
#   background-color: #94d390;
#   color: #000000;
# }
# #T_68897_row45_col6 {
#   background-color: #95d391;
#   color: #000000;
# }
# #T_68897_row46_col6 {
#   background-color: #97d492;
#   color: #000000;
# }
# #T_68897_row47_col6 {
#   background-color: #99d595;
#   color: #000000;
# }
# #T_68897_row48_col6, #T_68897_row49_col6, #T_68897_row50_col6 {
#   background-color: #9bd696;
#   color: #000000;
# }
# #T_68897_row51_col6, #T_68897_row52_col6 {
#   background-color: #9cd797;
#   color: #000000;
# }
# #T_68897_row53_col6 {
#   background-color: #9ed798;
#   color: #000000;
# }
# #T_68897_row54_col6 {
#   background-color: #a0d99b;
#   color: #000000;
# }
# #T_68897_row55_col6 {
#   background-color: #a2d99c;
#   color: #000000;
# }
# #T_68897_row56_col6 {
#   background-color: #a4da9e;
#   color: #000000;
# }
# #T_68897_row57_col6, #T_68897_row58_col6, #T_68897_row59_col6, #T_68897_row60_col6 {
#   background-color: #a5db9f;
#   color: #000000;
# }
# #T_68897_row61_col6, #T_68897_row62_col6 {
#   background-color: #a8dca2;
#   color: #000000;
# }
# #T_68897_row63_col6 {
#   background-color: #a9dca3;
#   color: #000000;
# }
# #T_68897_row64_col6 {
#   background-color: #aadda4;
#   color: #000000;
# }
# #T_68897_row65_col6, #T_68897_row66_col6 {
#   background-color: #aedea7;
#   color: #000000;
# }
# #T_68897_row67_col6 {
#   background-color: #afdfa8;
#   color: #000000;
# }
# #T_68897_row68_col6 {
#   background-color: #b0dfaa;
#   color: #000000;
# }
# #T_68897_row69_col6 {
#   background-color: #b4e1ad;
#   color: #000000;
# }
# #T_68897_row70_col6 {
#   background-color: #b5e1ae;
#   color: #000000;
# }
# #T_68897_row71_col6 {
#   background-color: #b8e3b2;
#   color: #000000;
# }
# #T_68897_row72_col6 {
#   background-color: #bbe4b4;
#   color: #000000;
# }
# #T_68897_row73_col6 {
#   background-color: #bce4b5;
#   color: #000000;
# }
# #T_68897_row74_col6 {
#   background-color: #c8e9c1;
#   color: #000000;
# }
# #T_68897_row75_col6, #T_68897_row76_col6 {
#   background-color: #cbeac4;
#   color: #000000;
# }
# #T_68897_row77_col6 {
#   background-color: #ccebc6;
#   color: #000000;
# }
# #T_68897_row78_col6, #T_68897_row79_col6 {
#   background-color: #d0edca;
#   color: #000000;
# }
# #T_68897_row80_col6, #T_68897_row81_col6 {
#   background-color: #d1edcb;
#   color: #000000;
# }
# #T_68897_row82_col6, #T_68897_row83_col6 {
#   background-color: #d3eecd;
#   color: #000000;
# }
# #T_68897_row84_col6, #T_68897_row85_col6 {
#   background-color: #d5efcf;
#   color: #000000;
# }
# #T_68897_row86_col6, #T_68897_row87_col6, #T_68897_row88_col6 {
#   background-color: #d6efd0;
#   color: #000000;
# }
# #T_68897_row89_col6 {
#   background-color: #d8f0d2;
#   color: #000000;
# }
# #T_68897_row90_col6, #T_68897_row91_col6 {
#   background-color: #daf0d4;
#   color: #000000;
# }
# #T_68897_row92_col6 {
#   background-color: #dbf1d5;
#   color: #000000;
# }
# #T_68897_row93_col6, #T_68897_row94_col6 {
#   background-color: #dbf1d6;
#   color: #000000;
# }
# #T_68897_row95_col6 {
#   background-color: #dcf2d7;
#   color: #000000;
# }
# #T_68897_row96_col6 {
#   background-color: #def2d9;
#   color: #000000;
# }
# #T_68897_row97_col6 {
#   background-color: #dff3da;
#   color: #000000;
# }
# #T_68897_row98_col6 {
#   background-color: #e0f3db;
#   color: #000000;
# }
# #T_68897_row99_col6 {
#   background-color: #e3f4de;
#   color: #000000;
# }
# #T_68897_row100_col6 {
#   background-color: #e6f5e1;
#   color: #000000;
# }
# #T_68897_row101_col6 {
#   background-color: #e7f6e3;
#   color: #000000;
# }
# #T_68897_row102_col6 {
#   background-color: #e8f6e3;
#   color: #000000;
# }
# #T_68897_row103_col6 {
#   background-color: #edf8e9;
#   color: #000000;
# }
# #T_68897_row104_col6 {
#   background-color: #f0f9ed;
#   color: #000000;
# }
# #T_68897_row105_col6 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_68897_row106_col6, #T_68897_row107_col6 {
#   background-color: #f2faef;
#   color: #000000;
# }
# #T_68897_row108_col6 {
#   background-color: #f4fbf1;
#   color: #000000;
# }
# #T_68897_row109_col6, #T_68897_row110_col6 {
#   background-color: #f5fbf2;
#   color: #000000;
# }
# #T_68897_row111_col6 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_68897">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_68897_level0_col0" class="col_heading level0 col0" >STT Model (Whisper)</th>
#       <th id="T_68897_level0_col1" class="col_heading level0 col1" >MT Model (Translator)</th>
#       <th id="T_68897_level0_col2" class="col_heading level0 col2" >STT Quality Score</th>
#       <th id="T_68897_level0_col3" class="col_heading level0 col3" >MT Quality Score</th>
#       <th id="T_68897_level0_col4" class="col_heading level0 col4" >Total Score (Quality)</th>
#       <th id="T_68897_level0_col5" class="col_heading level0 col5" >Total Time (sec)</th>
#       <th id="T_68897_level0_col6" class="col_heading level0 col6" >Efficiency (Score ÷ Time)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_68897_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_68897_row0_col0" class="data row0 col0" >small</td>
#       <td id="T_68897_row0_col1" class="data row0 col1" >Gemini 2.0 Flash</td>
#       <td id="T_68897_row0_col2" class="data row0 col2" >16</td>
#       <td id="T_68897_row0_col3" class="data row0 col3" >15</td>
#       <td id="T_68897_row0_col4" class="data row0 col4" >31</td>
#       <td id="T_68897_row0_col5" class="data row0 col5" >10</td>
#       <td id="T_68897_row0_col6" class="data row0 col6" >3.100000</td>
#     </tr>
#     <tr>
#       <th id="T_68897_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_68897_row1_col0" class="data row1 col0" >base</td>
#       <td id="T_68897_row1_col1" class="data row1 col1" >Gemini 2.0 Flas
